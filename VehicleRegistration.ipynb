# %% [markdown]
# <a href="https://colab.research.google.com/github/nikolasleeb/INFO523_FinalProject/blob/main/VehicleRegistration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import statsmodels.api as sm
from scipy.stats import skew, kurtosis
from sklearn.preprocessing import StandardScaler
import glob, os

# %% [markdown]
# # Attach Data

# %%
'''Connects to Google Drive to load in data'''

# '''
# Connect to and mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Find the dataset in google drive and assign path to variable called 'Match'
matches = glob.glob('/content/drive/MyDrive/**/VehicleRegistrations.xlsx', recursive=True)
print("Found paths:", matches)

# Using 'Match' load in the dataset using the path
path = matches[0]
registrations = pd.read_excel(path, engine='openpyxl')
registrations.head()
# '''

'''
# Load dataset from local file for demonstration purposes
registrations = pd.read_excel('VehicleRegistrations.xlsx', engine='openpyxl')
registrations.head()
'''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found paths: ['/content/drive/MyDrive/DataMiningFall25/INFO 523 Final Project/Datasets/VehicleRegistration/VehicleRegistrations.xlsx']
# "\n# Load dataset from local file for demonstration purposes\nregistrations = pd.read_excel('VehicleRegistrations.xlsx', engine='openpyxl')\nregistrations.head()\n"

# %%
colors = { "registrations": "royalblue" }

# %%
''' check for null and missing values'''
registrations.isnull().sum()
# Out:
# Inventory    0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# 2014         0
# 2015         0
# 2016         0
# 2017         0
# 2018         0
# 2019         0
# 2020         0
# 2021         0
# dtype: int64

# %% [markdown]
# # Cleaning and Transforming

# %%
''' Transpose the table so that years become the first column '''

id_col = registrations.columns[0]            # e.g. "Fuel economy, mpg"
registrations = registrations.round(2)
registrations = registrations.set_index(id_col).T.reset_index().rename(columns={'index':'Year'})

registrations.head()
# Out:
# Inventory       Year  Automobile_Registrations  Motorcycle_Registrations  \
# 0         1995-01-01               136066045.0                3767029.00
# 1         1996-01-01               129728341.0                3871237.14
# 2         1997-01-01               129748704.0                3826373.00
# 3         1998-01-01               131838538.0                3879450.00
# 4         1999-01-01               132432044.0                4152433.00
#
# Inventory  Licensed_Drivers  Z_automobile_registrations  \
# 0               176628482.0                        0.91
# 1               179539340.0                        0.38
# 2               182709204.0                        0.38
# 3               184860969.0                        0.55
# 4               187170420.0                        0.60
#
# Inventory  Z_motorcycle_registrations  Z_licensed_drivers
# 0                               -1.54               -1.79
# 1                               -1.48               -1.61
# 2                               -1.51               -1.41
# 3                               -1.48               -1.28
# 4                               -1.34               -1.14

# %%
''' Verify the columns, datatypes, and number of entries'''
registrations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Year                                        27 non-null     int64
#  1   Number of Automobile Vehicle Registrations  27 non-null     float64
#  2   Number of Motorcycle Vehicle Registrations  27 non-null     float64
#  3   Motor vehicle licensed drivers              27 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 996.0 bytes

# %%
''' Data Cleaning for registrations Data '''

# Convert Year column to Year format
registrations["Year"] = pd.to_datetime(registrations["Year"], format='%Y')

# Filter to keep data where the year is between 1995 and 2021 (inclusive)
registrations = registrations[
    (registrations["Year"].dt.year >= 1995) &
    (registrations["Year"].dt.year <= 2021)
]

# Preview the first 10 rows
registrations.head(10)
# Out:
# Inventory       Year  Number of Automobile Vehicle Registrations  \
# 0         1995-01-01                                 136066045.0
# 1         1996-01-01                                 129728341.0
# 2         1997-01-01                                 129748704.0
# 3         1998-01-01                                 131838538.0
# 4         1999-01-01                                 132432044.0
# 5         2000-01-01                                 133621420.0
# 6         2001-01-01                                 137633467.0
# 7         2002-01-01                                 135920677.0
# 8         2003-01-01                                 135669897.0
# 9         2004-01-01                                 136430651.0
#
# Inventory  Number of Motorcycle Vehicle Registrations  \
# 0                                          3767029.00
# 1                                          3871237.14
# 2                                          3826373.00
# 3                                          3879450.00
# 4                                          4152433.00
# 5                                          4346068.00
# 6                                          4903056.00
# 7                                          5004156.00
# 8                                          5370035.00
# 9                                          5780870.00
#
# Inventory  Motor vehicle licensed drivers
# 0                             176628482.0
# 1                             179539340.0
# 2                             182709204.0
# 3                             184860969.0
# 4                             187170420.0
# 5                             190625023.0
# 6                             191275719.0
# 7                             194295633.0
# 8                             196165667.0
# 9                             198888912.0

# %%
''' Rename columns for easier access '''
registrations = registrations.rename(columns={
    'Number of Automobile Vehicle Registrations': 'Automobile_Registrations',
    'Number of Motorcycle Vehicle Registrations': 'Motorcycle_Registrations',
    'Motor vehicle licensed drivers': 'Licensed_Drivers'
})

# %% [markdown]
# # Summary Stats

# %%
registrations.describe()
# Out:
# Inventory                 Year  Automobile_Registrations  \
# count                       27              2.700000e+01
# mean       2008-01-01 08:53:20              1.251580e+08
# min        1995-01-01 00:00:00              1.029739e+08
# 25%        2001-07-02 12:00:00              1.129127e+08
# 50%        2008-01-01 00:00:00              1.308922e+08
# 75%        2014-07-02 12:00:00              1.357953e+08
# max        2021-01-01 00:00:00              1.376335e+08
# std                        NaN              1.204000e+07
#
# Inventory  Motorcycle_Registrations  Licensed_Drivers
# count                  2.700000e+01      2.700000e+01
# mean                   6.806726e+06      2.056301e+08
# min                    3.767029e+06      1.766285e+08
# 25%                    4.953606e+06      1.927857e+08
# 50%                    7.752926e+06      2.083206e+08
# 75%                    8.446220e+06      2.160885e+08
# max                    9.881414e+06      2.327818e+08
# std                    1.977060e+06      1.623333e+07

# %%
'''' View skewness and kurtosis of consumption data '''

columns_to_analyze = registrations.columns[1:]  # Exclude the 'Year' column

for column in columns_to_analyze:
    skewness = skew(registrations[column].dropna())
    kurt = kurtosis(registrations[column].dropna())
    print(f"Column: {column}")
    print(f"  Skewness: {skewness:.4f}")
    print(f"  Kurtosis: {kurt:.4f}\n")
# Out:
# Column: Automobile_Registrations
#   Skewness: -0.5179
#   Kurtosis: -1.4172
#
# Column: Motorcycle_Registrations
#   Skewness: -0.3593
#   Kurtosis: -1.4021
#
# Column: Licensed_Drivers
#   Skewness: -0.0799
#   Kurtosis: -1.0196

# %%
''' View registrations date range and total years of data '''

print("Earliest date:", registrations["Year"].min())
print("Latest date:", registrations["Year"].max())
print("Total months of data:", len(registrations))
# Out:
# Earliest date: 1995-01-01 00:00:00
# Latest date: 2021-01-01 00:00:00
# Total months of data: 27

# %% [markdown]
# # Automobile Registrations

# %% [markdown]
# - number of new drivers

# %%
''' Calculate and print average automobile registrations, standard deviation, and coefficient of variation '''

mean = registrations["Automobile_Registrations"].mean()
std = registrations["Automobile_Registrations"].std()
cv = (std / mean) * 100
print(f"Average monthly Automobile Registrations: {mean:,.2f}")
print(f"Standard deviation: {std:,.2f}")
print(f"Coefficient of variation: {cv:.2f}% \n")
# Out:
# Average monthly Automobile Registrations: 125,157,985.01
# Standard deviation: 12,040,001.98
# Coefficient of variation: 9.62%

# %%
''' Create a histogram to visualize the distribution of Automobile Registrations '''

# Create histogram
figr1 = px.histogram(
    registrations,
    x="Automobile_Registrations",
    nbins=8,
    title="Distribution of Automobile Registrations",
    color_discrete_sequence=[colors["registrations"]]
)

# Customize layout
figr1.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Automobile Registrations",
    yaxis_title="Frequency",
    xaxis=dict(showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    hovermode="x unified",
    height=500
)

figr1.update_traces(marker_line_color="black", marker_line_width=1, opacity=1)

figr1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f9b7843-3574-48c3-a894-d3e4ecea7fe3" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f9b7843-3574-48c3-a894-d3e4ecea7fe3")) {                    Plotly.newPlot(                        "8f9b7843-3574-48c3-a894-d3e4ecea7fe3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Automobile_Registrations=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"royalblue","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"","nbinsx":8,"offsetgroup":"","orientation":"v","showlegend":false,"x":[136066045.0,129728341.0,129748704.0,131838538.0,132432044.0,133621420.0,137633467.0,135920677.0,135669897.0,136430651.0,136568083.0,135399945.0,135932930.0,137079843.0,134879600.0,130892240.0,125656528.0,111289906.47,113676345.0,113898844.71,112864228.0,112961266.0,111177029.0,111242132.0,108547710.0,105135300.0,102973881.04],"xaxis":"x","yaxis":"y","type":"histogram","opacity":1}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{ ...

# %%
''' Outlier Detection for Automobile Registrations using Z-Score Method and Box Plot '''

# Use an existing column name from the DataFrame (e.g., "Car")
col_name = "Automobile_Registrations"

# Compute Z-score for the selected column
registrations["Z_automobile_registrations"] = (
    (registrations[col_name] - registrations[col_name].mean())
    / registrations[col_name].std()
)

# Flag potential outliers (|Z| > 3)
registrations_outliers = registrations[np.abs(registrations["Z_automobile_registrations"]) > 3]
print(f"Detected {len(registrations_outliers)} potential outliers in '{col_name}' registrations.")
display(registrations_outliers[["Year", col_name, "Z_automobile_registrations"]])

# visual outlier detection with box plot
figr3 = px.box(
    registrations,
    y=col_name,
    title=f"Outlier Detection: {col_name} Registrations",
    points="all",
)
figr3.update_layout(template="plotly_white", title_x=0.5, height=500)
figr3.show()
# Out:
# Detected 0 potential outliers in 'Automobile_Registrations' registrations.
# Empty DataFrame
# Columns: [Year, Automobile_Registrations, Z_automobile_registrations]
# Index: []
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0042dddb-9d6f-46f8-898a-48aad00532b8" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0042dddb-9d6f-46f8-898a-48aad00532b8")) {                    Plotly.newPlot(                        "0042dddb-9d6f-46f8-898a-48aad00532b8",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Automobile_Registrations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[136066045.0,129728341.0,129748704.0,131838538.0,132432044.0,133621420.0,137633467.0,135920677.0,135669897.0,136430651.0,136568083.0,135399945.0,135932930.0,137079843.0,134879600.0,130892240.0,125656528.0,111289906.47,113676345.0,113898844.71,112864228.0,112961266.0,111177029.0,111242132.0,108547710.0,105135300.0,102973881.04],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type": ...

# %% [markdown]
# # Motorcycle Registrations

# %%
''' Calculate and print average yearly motorcycle registrations, standard deviation, and coefficient of variation '''

mean = registrations["Motorcycle_Registrations"].mean()
std = registrations["Motorcycle_Registrations"].std()
cv = (std / mean) * 100
print(f"Average monthly motorcycle registrations: {mean:,.2f}")
print(f"Standard deviation: {std:,.2f}")
print(f"Coefficient of variation: {cv:.2f}% \n")
# Out:
# Average monthly motorcycle registrations: 6,806,726.41
# Standard deviation: 1,977,060.34
# Coefficient of variation: 29.05%

# %%
''' Create a histogram to visualize the distribution of Motorcycle Registrations '''

# Create histogram
figr2 = px.histogram(
    registrations,
    x="Motorcycle_Registrations",
    nbins=8,
    title="Distribution of Motorcycle Registrations",
    color_discrete_sequence=[colors["registrations"]]
)

# Customize layout
figr2.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Motorcycle Registrations",
    yaxis_title="Frequency",
    xaxis=dict(showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    hovermode="x unified",
    height=500
)

figr2.update_traces(marker_line_color="black", marker_line_width=1, opacity=1)

figr2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4d1f0af-4eaa-4888-8c3e-79f7bef9531c" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4d1f0af-4eaa-4888-8c3e-79f7bef9531c")) {                    Plotly.newPlot(                        "b4d1f0af-4eaa-4888-8c3e-79f7bef9531c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Motorcycle_Registrations=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"royalblue","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"","nbinsx":8,"offsetgroup":"","orientation":"v","showlegend":false,"x":[3767029.0,3871237.14,3826373.0,3879450.0,4152433.0,4346068.0,4903056.0,5004156.0,5370035.0,5780870.0,6227146.0,6678958.0,7138475.79,7752925.69,7929724.0,8009503.0,8437502.0,8454939.0,8404687.0,8417717.5,8600936.0,8679380.0,8664108.0,8659741.13,8596313.89,8347435.0,9881414.0],"xaxis":"x","yaxis":"y","type":"histogram","opacity":1}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10, ...

# %%
''' Outlier Detection for Motorcycle Registrations using Z-Score Method and Box Plot '''

# Use an existing column name from the DataFrame (e.g., "Car")
col_name = "Motorcycle_Registrations"

# Compute Z-score for the selected column
registrations["Z_motorcycle_registrations"] = (
    (registrations[col_name] - registrations[col_name].mean())
    / registrations[col_name].std()
)

# Flag potential outliers (|Z| > 3)
registrations_outliers = registrations[np.abs(registrations["Z_motorcycle_registrations"]) > 3]
print(f"Detected {len(registrations_outliers)} potential outliers in '{col_name}' registrations.")
display(registrations_outliers[["Year", col_name, "Z_motorcycle_registrations"]])

# visual outlier detection with box plot
figr3 = px.box(
    registrations,
    y=col_name,
    title=f"Outlier Detection: {col_name}",
    points="all",
)
figr3.update_layout(template="plotly_white", title_x=0.5, height=500)
figr3.show()
# Out:
# Detected 0 potential outliers in 'Motorcycle_Registrations' registrations.
# Empty DataFrame
# Columns: [Year, Motorcycle_Registrations, Z_motorcycle_registrations]
# Index: []
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="27c2b5b9-1a3d-4734-a1af-11b54298f681" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27c2b5b9-1a3d-4734-a1af-11b54298f681")) {                    Plotly.newPlot(                        "27c2b5b9-1a3d-4734-a1af-11b54298f681",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Motorcycle_Registrations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[3767029.0,3871237.14,3826373.0,3879450.0,4152433.0,4346068.0,4903056.0,5004156.0,5370035.0,5780870.0,6227146.0,6678958.0,7138475.79,7752925.69,7929724.0,8009503.0,8437502.0,8454939.0,8404687.0,8417717.5,8600936.0,8679380.0,8664108.0,8659741.13,8596313.89,8347435.0,9881414.0],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth": ...

# %% [markdown]
# # Licensed Drivers

# %%
''' Calculate and print average yearly licensed drivers, standard deviation, and coefficient of variation '''

mean = registrations["Licensed_Drivers"].mean()
std = registrations["Licensed_Drivers"].std()
cv = (std / mean) * 100
print(f"Average monthly licensed drivers: {mean:,.2f}")
print(f"Standard deviation: {std:,.2f}")
print(f"Coefficient of variation: {cv:.2f}% \n")
# Out:
# Average monthly licensed drivers: 205,630,124.95
# Standard deviation: 16,233,334.02
# Coefficient of variation: 7.89%

# %%
''' Create a histogram to visualize the distribution of License Drivers '''

# Create histogram
figr3 = px.histogram(
    registrations,
    x="Licensed_Drivers",
    nbins=12,
    title="Distribution of License Drivers",
    color_discrete_sequence=[colors["registrations"]]
)

# Customize layout
figr3.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Licensed Drivers",
    yaxis_title="Frequency",
    xaxis=dict(showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    hovermode="x unified",
    height=500
)

figr3.update_traces(marker_line_color="black", marker_line_width=1, opacity=1)

figr3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35e04bfe-89e3-445e-a8c8-d330310160be" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35e04bfe-89e3-445e-a8c8-d330310160be")) {                    Plotly.newPlot(                        "35e04bfe-89e3-445e-a8c8-d330310160be",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Licensed_Drivers=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"royalblue","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"","nbinsx":12,"offsetgroup":"","orientation":"v","showlegend":false,"x":[176628482.0,179539340.0,182709204.0,184860969.0,187170420.0,190625023.0,191275719.0,194295633.0,196165667.0,198888912.0,200665267.0,202810438.0,205741845.0,208320601.0,209618386.0,210114939.25,211874649.16,211814830.0,212159728.0,214092471.75,218084465.26,221994424.0,225346257.0,227558384.77,228679719.17,228195802.4,232781797.0],"xaxis":"x","yaxis":"y","type":"histogram","opacity":1}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"mar ...

# %%
''' Outlier Detection for Licensed Driver using Z-Score Method and Box Plot '''

# Use an existing column name from the DataFrame (e.g., "Car")
col_name = "Licensed_Drivers"

# Compute Z-score for the selected column
registrations["Z_licensed_drivers"] = (
    (registrations[col_name] - registrations[col_name].mean())
    / registrations[col_name].std()
)

# Flag potential outliers (|Z| > 3)
registrations_outliers = registrations[np.abs(registrations["Z_licensed_drivers"]) > 3]
print(f"Detected {len(registrations_outliers)} potential outliers in '{col_name}' registrations.")
display(registrations_outliers[["Year", col_name, "Z_licensed_drivers"]])

# visual outlier detection with box plot
figr3 = px.box(
    registrations,
    y=col_name,
    title=f"Outlier Detection: {col_name}",
    points="all",
)
figr3.update_layout(template="plotly_white", title_x=0.5, height=500)
figr3.show()
# Out:
# Detected 0 potential outliers in 'Licensed_Drivers' registrations.
# Empty DataFrame
# Columns: [Year, Licensed_Drivers, Z_licensed_drivers]
# Index: []
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="54dede83-603b-47ac-8d83-61c1e6abd863" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54dede83-603b-47ac-8d83-61c1e6abd863")) {                    Plotly.newPlot(                        "54dede83-603b-47ac-8d83-61c1e6abd863",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Licensed_Drivers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[176628482.0,179539340.0,182709204.0,184860969.0,187170420.0,190625023.0,191275719.0,194295633.0,196165667.0,198888912.0,200665267.0,202810438.0,205741845.0,208320601.0,209618386.0,210114939.25,211874649.16,211814830.0,212159728.0,214092471.75,218084465.26,221994424.0,225346257.0,227558384.77,228679719.17,228195802.4,232781797.0],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"hist ...

# %% [markdown]
# # Line Graph

# %%
''' create a line graph showing trends over time for each vehicle type '''

fig_line = px.line(
    registrations,
    x="Year",
    y=["Automobile_Registrations", "Motorcycle_Registrations", "Licensed_Drivers"],
    title="Vehicle Registration Trends Over Time by Vehicle Type",
    labels={"value": "Number of Registrations", "variable": "Vehicle Type"},
    color_discrete_sequence=px.colors.qualitative.Set1
)
fig_line.update_layout(
    template="plotly_white",
    title_x=0.5,
    xaxis_title="Year",
    yaxis_title="Number of Registrations",
    xaxis=dict(showgrid=True, gridcolor="lightgray"),
    yaxis=dict(showgrid=True, gridcolor="lightgray"),
    hovermode="x unified",
    height=600
)
fig_line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d80e9154-e20d-494a-bd21-d27470c584cf" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d80e9154-e20d-494a-bd21-d27470c584cf")) {                    Plotly.newPlot(                        "d80e9154-e20d-494a-bd21-d27470c584cf",                        [{"hovertemplate":"Vehicle Type=Automobile_Registrations\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Registrations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Automobile_Registrations","line":{"color":"rgb(228,26,28)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Automobile_Registrations","orientation":"v","showlegend":true,"x":["1995-01-01T00:00:00","1996-01-01T00:00:00","1997-01-01T00:00:00","1998-01-01T00:00:00","1999-01-01T00:00:00","2000-01-01T00:00:00","2001-01-01T00:00:00","2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00"],"xaxis":"x","y":[136066045.0,129728341.0,129748704.0,131838538.0,132432044.0,133621420.0,137633467.0,135920677.0,135669897.0,136430651.0,136568083.0,135399945.0,135932930.0,137079843.0,134879600.0,130892240.0,125656528.0,111289906.47,113676345.0,113898844.71,112864228.0,112961266.0,111177029.0,111242132.0,108547710.0,105135300.0,102973881.04],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vehicle Type=Motorcycle_Registrations\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Registrations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Motorcycle_Registrations","line":{"color":"rgb(55,126,184)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Motorcycle_Registrations","orientation":"v","showlegend":true,"x":["1995-01-01T00:00:00","1996-01-01T00:00:00","1997-01-01T00:00:00","1998-01-01T00:00:00","1999-01-01T00:00:00","2000-01-01T00:00:00","2001-01-01T00:00:00","2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00"],"xaxis":"x","y":[3767029.0,3871237.14,3826373.0,3879450.0,4152433.0,4346068.0,4903056.0,5004156.0,5370035.0,5780870.0,6227146.0,6678958.0,7138475.79,7752925.69,7929724.0,8009503.0,8437502.0,8454939.0,8404687.0,8417717.5,8600936.0,8679380.0,8664108.0,8659741.13,8596313.89,8347435.0,9881414.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Vehicle Type=Licensed_Drivers\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Registrations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Licensed_Drivers","line":{"color":"rgb(77,175,74)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Licensed_Drivers","orientation":"v","showlegend":true,"x":["1995-01-01T00:00:00","1996-01-01T00:00:00","1997-01-01T00:00:00","1998-01-01T00:00:00","1999-01-01T00:00:00","2000-01-01T00:00:00","2001-01-01T00:00:00","2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00: ...
